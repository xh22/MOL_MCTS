# %%
from rdkit import Chem
from rdkit.Chem import AllChem as Chem

from rdkit.Chem import Draw

m = Chem.MolFromSmiles('COCc1cccc(C[C@@H]2CCN(c3ncnc4[nH]ccc34)C2)c1')
Draw.MolToImage(m)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F911C4E6FD0>
