# %%
from rdkit import Chem
from rdkit.Chem import AllChem as Chem

from rdkit.Chem import Draw

m = Chem.MolFromSmiles('OCc1cccc(C[C@@H]2CCN(c3ncnc4[nH]ccc34)C2)c1')
Draw.MolToImage(m)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F282C588400>

# %%
m = Chem.MolFromSmiles('OCc1cccc(C[C@@H]2CCN(c3ncnc4[nH]ccc34)C2)c1')
Draw.MolToImage(m)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7EFF98051780>

# %%
import numpy as np
np.random.choice([1,2], 1)[0]
# Out:
# 2

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6c10289a8da7> in <module>
# ----> 1 p
#
# NameError: name 'p' is not defined
